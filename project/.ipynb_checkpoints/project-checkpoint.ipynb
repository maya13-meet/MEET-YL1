# %%
import csv

# %%
data = open('environmental.csv', 'rb')
reader = csv.reader(data)
rownum = 0
ozone = []
radiation = []
temperature = []
wind = []
for row in reader:
    if rownum == 0:
        header = row
    else:
        
        ozone.append(row[0])
        radiation.append(row[1])
        temperature.append(row[2])
        wind.append(row[3])
    rownum+=1

print ozone
for i in ozone:
    ozone1 = map(float, i)
    
    
print ozone1
print radiation
print temperature
print wind

data.close
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-e1a0aae0737d> in <module>()
#      18
#      19 print ozone
# ---> 20 ozone1 = map(math.floor, ozone)
#      21 for i in ozone:
#      22     ozone1 = map(float, i)
#
# TypeError: a float is required
# ...
